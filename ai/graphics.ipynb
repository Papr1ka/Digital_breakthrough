# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_subm = pd.read_csv("dataset\\subm_train.csv", sep = ';', encoding = 'utf-8')
df_train = pd.read_csv("dataset\\train.csv", sep = ';', encoding = 'utf-8')

# %%
df_subm.head()
# Out:
#    object_id     img_name    group
# 0   10669820  7862029.jpg  Техника
# 1    4489444  9461061.jpg  Техника
# 2    8722586  5095122.jpg  Техника
# 3    3712248   551422.jpg  Техника
# 4    6339754  2592073.jpg  Техника

# %%
df_train.head()["description"]
# Out:
# 0    сероглиняный, лепной, со сплошным белым ангобо...
# 1    На стволе имеется надульник, на  торце которог...
# 2    Прямоугольная пластина с усечёнными углами и д...
# 3     Корпус модели, надстройки, шлюпки выполнены и...
# 4                                                  NaN
# Name: description, dtype: object

# %%
df_train["object_id"] == 10669820
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20340    False
# 20341    False
# 20342    False
# 20343    False
# 20344    False
# Name: object_id, Length: 20345, dtype: bool

# %%
amounts = []
for obj_id in df_train["object_id"]:
    amounts.append(sum(df_train["object_id"] == obj_id))

# %%
ax = plt.figure(figsize=(10, 20))
plt.hist(np.log(amounts));

# %%
def f_metric(given, ideal):
    tp, tn, fp, fn = 0, 0, 0, 0
    for i in range(len(given)):
        given[i]
